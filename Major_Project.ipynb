# %% [markdown]
# <a href="https://colab.research.google.com/github/deemanth-05/ImageClassifier-App-Streamlit/blob/main/Major_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Python - April/Data Science/Corona.csv')
df.head()
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.511
# 1      AFG      Asia  ...           64.83                   0.511
# 2      AFG      Asia  ...           64.83                   0.511
# 3      AFG      Asia  ...           64.83                   0.511
# 4      AFG      Asia  ...           64.83                   0.511
#
# [5 rows x 59 columns]

# %%
 df.shape
# Out:
# (91487, 59)

# %%
df.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 4345
# location                                     0
# date                                         0
# total_cases                               2751
# new_cases                                 2752
# new_cases_smoothed                        3759
# total_deaths                             12617
# new_deaths                               12459
# new_deaths_smoothed                       3759
# total_cases_per_million                   3226
# new_cases_per_million                     3227
# new_cases_smoothed_per_million            4229
# total_deaths_per_million                 13079
# new_deaths_per_million                   12921
# new_deaths_smoothed_per_million           4229
# reproduction_rate                        17936
# icu_patients                             82176
# icu_patients_per_million                 82176
# hosp_patients                            79910
# ...

# %%
df = df.drop(columns=['iso_code','new_cases_smoothed','new_deaths_smoothed','new_cases_smoothed_per_million','new_deaths_smoothed_per_million','reproduction_rate','icu_patients','icu_patients_per_million','hosp_patients','hosp_patients_per_million','new_tests_smoothed','new_tests_smoothed_per_thousand','tests_units','new_vaccinations_smoothed','total_vaccinations_per_hundred','people_vaccinated_per_hundred','people_fully_vaccinated_per_hundred','new_vaccinations_smoothed_per_million','stringency_index','median_age','aged_65_older','aged_70_older','gdp_per_capita','extreme_poverty','cardiovasc_death_rate','diabetes_prevalence','female_smokers','male_smokers','handwashing_facilities','life_expectancy','human_development_index','total_cases_per_million','new_cases_per_million','weekly_icu_admissions_per_million','weekly_hosp_admissions_per_million','total_tests_per_thousand','new_tests_per_thousand'])
df.head()
# Out:
#   continent     location  ... population_density  hospital_beds_per_thousand
# 0      Asia  Afghanistan  ...             54.422                         0.5
# 1      Asia  Afghanistan  ...             54.422                         0.5
# 2      Asia  Afghanistan  ...             54.422                         0.5
# 3      Asia  Afghanistan  ...             54.422                         0.5
# 4      Asia  Afghanistan  ...             54.422                         0.5
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (91487, 22)

# %%
col = ['total_deaths','new_deaths','total_deaths_per_million','new_deaths_per_million','weekly_icu_admissions','weekly_hosp_admissions','new_tests','total_tests','positive_rate','tests_per_case','total_vaccinations','people_vaccinated','people_fully_vaccinated','new_vaccinations']
df[col] = df[col].fillna(0)

# %%
df.head()
# Out:
#   continent     location  ... population_density  hospital_beds_per_thousand
# 0      Asia  Afghanistan  ...             54.422                         0.5
# 1      Asia  Afghanistan  ...             54.422                         0.5
# 2      Asia  Afghanistan  ...             54.422                         0.5
# 3      Asia  Afghanistan  ...             54.422                         0.5
# 4      Asia  Afghanistan  ...             54.422                         0.5
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['continent', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_deaths_per_million',
#        'new_deaths_per_million', 'weekly_icu_admissions',
#        'weekly_hosp_admissions', 'new_tests', 'total_tests', 'positive_rate',
#        'tests_per_case', 'total_vaccinations', 'people_vaccinated',
#        'people_fully_vaccinated', 'new_vaccinations', 'population',
#        'population_density', 'hospital_beds_per_thousand'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# continent                      4345
# location                          0
# date                              0
# total_cases                    2751
# new_cases                      2752
# total_deaths                      0
# new_deaths                        0
# total_deaths_per_million          0
# new_deaths_per_million            0
# weekly_icu_admissions             0
# weekly_hosp_admissions            0
# new_tests                         0
# total_tests                       0
# positive_rate                     0
# tests_per_case                    0
# total_vaccinations                0
# people_vaccinated                 0
# people_fully_vaccinated           0
# new_vaccinations                  0
# population                      607
# population_density             6400
# hospital_beds_per_thousand    16212
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#       continent     location  ... population_density  hospital_beds_per_thousand
# 0          Asia  Afghanistan  ...             54.422                         0.5
# 1          Asia  Afghanistan  ...             54.422                         0.5
# 2          Asia  Afghanistan  ...             54.422                         0.5
# 3          Asia  Afghanistan  ...             54.422                         0.5
# 4          Asia  Afghanistan  ...             54.422                         0.5
# ...         ...          ...  ...                ...                         ...
# 91482    Africa     Zimbabwe  ...             42.729                         1.7
# 91483    Africa     Zimbabwe  ...             42.729                         1.7
# 91484    Africa     Zimbabwe  ...             42.729                         1.7
# 91485    Africa     Zimbabwe  ...             42.729                         1.7
# 91486    Africa     Zimbabwe  ...             42.729                         1.7
#
# ...

# %%
df.isnull().sum()
# Out:
# continent                     0
# location                      0
# date                          0
# total_cases                   0
# new_cases                     0
# total_deaths                  0
# new_deaths                    0
# total_deaths_per_million      0
# new_deaths_per_million        0
# weekly_icu_admissions         0
# weekly_hosp_admissions        0
# new_tests                     0
# total_tests                   0
# positive_rate                 0
# tests_per_case                0
# total_vaccinations            0
# people_vaccinated             0
# people_fully_vaccinated       0
# new_vaccinations              0
# population                    0
# population_density            0
# hospital_beds_per_thousand    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73745 entries, 0 to 91486
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   continent                   73745 non-null  object
#  1   location                    73745 non-null  object
#  2   date                        73745 non-null  object
#  3   total_cases                 73745 non-null  float64
#  4   new_cases                   73745 non-null  float64
#  5   total_deaths                73745 non-null  float64
#  6   new_deaths                  73745 non-null  float64
#  7   total_deaths_per_million    73745 non-null  float64
#  8   new_deaths_per_million      73745 non-null  float64
#  9   weekly_icu_admissions       73745 non-null  float64
#  10  weekly_hosp_admissions      73745 non-null  float64
#  11  new_tests                   73745 non-null  float64
#  12  total_tests                 73745 non-null  float64
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
df['total_cases'] = df['total_cases'].astype(int)
df['new_cases'] = df['new_cases'].astype(int)
df['total_deaths'] = df['total_deaths'].astype(int)
df['new_deaths'] = df['new_deaths'].astype(int)
df['weekly_icu_admissions'] = df['weekly_icu_admissions'].astype(int)
df['weekly_hosp_admissions'] = df['weekly_hosp_admissions'].astype(int)
df['new_tests'] = df['new_tests'].astype(int)
df['total_tests'] = df['total_tests'].astype(int)
df['positive_rate'] = df['positive_rate'].astype(int)
df['tests_per_case'] = df['tests_per_case'].astype(int)
df['total_vaccinations'] = df['total_vaccinations'].astype(int)
df['people_vaccinated'] = df['people_vaccinated'].astype(int)
df['people_fully_vaccinated'] = df['people_fully_vaccinated'].astype(int)
df['new_vaccinations'] = df['new_vaccinations'].astype(int)
df['population'] = df['population'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73745 entries, 0 to 91486
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   continent                   73745 non-null  object
#  1   location                    73745 non-null  object
#  2   date                        73745 non-null  datetime64[ns]
#  3   total_cases                 73745 non-null  int64
#  4   new_cases                   73745 non-null  int64
#  5   total_deaths                73745 non-null  int64
#  6   new_deaths                  73745 non-null  int64
#  7   total_deaths_per_million    73745 non-null  float64
#  8   new_deaths_per_million      73745 non-null  float64
#  9   weekly_icu_admissions       73745 non-null  int64
#  10  weekly_hosp_admissions      73745 non-null  int64
#  11  new_tests                   73745 non-null  int64
#  12  total_tests                 73745 non-null  int64
# ...

# %%
df_india = df[df['location'] == 'India']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.plot(df_india['date'],df_india['total_deaths'])
plt.plot(df_india['date'],df_india['total_deaths'].rolling(10).mean())

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.plot(df_india['date'],df_india['total_cases'])
plt.plot(df_india['date'],df_india['total_cases'].rolling(10).mean())

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.plot(df_india['date'],df_india['people_vaccinated'])
plt.plot(df_india['date'],df_india['people_vaccinated'].rolling(10).mean())

# %%
df_india = df_india.rename(columns = {'total_cases':'y','date':'ds'})
#df_india = df_india.rename(columns = {'total_deaths':'y','date':'ds'})
#df_india = df_india.rename(columns = {'people_vaccinated':'y','date':'ds'})

# %%
df_india
# Out:
#       continent location  ... population_density  hospital_beds_per_thousand
# 37830      Asia    India  ...            450.419                        0.53
# 37831      Asia    India  ...            450.419                        0.53
# 37832      Asia    India  ...            450.419                        0.53
# 37833      Asia    India  ...            450.419                        0.53
# 37834      Asia    India  ...            450.419                        0.53
# ...         ...      ...  ...                ...                         ...
# 38308      Asia    India  ...            450.419                        0.53
# 38309      Asia    India  ...            450.419                        0.53
# 38310      Asia    India  ...            450.419                        0.53
# 38311      Asia    India  ...            450.419                        0.53
# 38312      Asia    India  ...            450.419                        0.53
#
# [483 rows x 22 columns]

# %%
from fbprophet import Prophet
model = Prophet(changepoint_prior_scale=0.2)
model.fit(df_india)
x = model.make_future_dataframe(periods = 100,freq='D')
forecast = model.predict(x)
df2 = forecast[['ds','trend','yhat_lower','yhat_upper','yhat']]
model.plot(forecast,figsize=(20,10))
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
model.plot(forecast,figsize=(20,10))
